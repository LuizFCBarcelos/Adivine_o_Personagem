# %% [markdown]
# # Adivinhe o Personagem por Características — Random Foret
# Aluno: Luiz Fernando de Campos Barcelos
# Data: 27/11/2025
#
# Este notebook usa Random Forest para adivinhar o personagem dada as características: magia, forca e inteligencia.

# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
dados = pandas.read_csv("personagens.csv")

X = dados[["magia", "forca", "inteligencia"]]
y = dados["personagem"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.5, random_state=42
)

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
acc = accuracy_score(y_test, y_pred)
print(f"Acurácia (Random Forest): {acc:.2f}\n")
print("Relatório de classificação:\n")
print(classification_report(y_test, y_pred))
# Out:
# Acurácia (Random Forest): 0.00
#
# Relatório de classificação:
#
#                   precision    recall  f1-score   support
#
#          Aquaman       0.00      0.00      0.00       1.0
#  Capitão América       0.00      0.00      0.00       1.0
#         Ciborgue       0.00      0.00      0.00       0.0
#          Ciclope       0.00      0.00      0.00       1.0
#      Constantine       0.00      0.00      0.00       0.0
#         Deadpool       0.00      0.00      0.00       0.0
#   Doutor Destino       0.00      0.00      0.00       1.0
#  Doutor Estranho       0.00      0.00      0.00       1.0
#            Groot       0.00      0.00      0.00       1.0
#     Homem-Aranha       0.00      0.00      0.00       1.0
#             Hulk       0.00      0.00      0.00       1.0
#   Lanterna Verde       0.00      0.00      0.00       1.0
#             Lobo       0.00      0.00      0.00       1.0
#          Magneto       0.00      0.00      0.00       0.0
# ...

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(14, 10))
plt.imshow(cm, interpolation='nearest')
plt.title('Matriz de Confusão - Random Forest', fontsize=16)
plt.colorbar()

# Usar apenas as classes presentes no conjunto de teste
classes_teste = np.unique(y_test)

tick_marks = np.arange(len(classes_teste))
plt.xticks(tick_marks, classes_teste, rotation=90, fontsize=9)
plt.yticks(tick_marks, classes_teste, fontsize=9)

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, cm[i, j],
                 ha="center", va="center",
                 color="black" if cm[i, j] < cm.max()/2 else "white",
                 fontsize=8)

plt.xlabel('Previsto', fontsize=12)
plt.ylabel('Real', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Conclusão - Random Forest
#
# Resumo: Random Forest combina várias árvores para melhorar decisões.
# Interpretação simples: comparar a acurácia deste notebook com a do SVM e do KNN para ver qual foi melhor com este dataset.
